# %% [markdown]
# <a href="https://colab.research.google.com/github/banerjee109/Infotact-Data-Team-2/blob/main/cohort_retention_cltv_analysis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

np.random.seed(7)
random.seed(7)

# ============================================================
# CloudSync SaaS — Subscription Billing Dataset
# Simulates 18 months of subscription history for a B2B SaaS product
# ============================================================

NUM_CUSTOMERS = 2500
START_DATE = datetime(2023, 1, 1)
NUM_MONTHS = 18

PLAN_TIERS = {
    'Starter':    {'mrr': 15,  'churn_risk': 0.14},   # cheap plan -> churns faster
    'Growth':     {'mrr': 49,  'churn_risk': 0.08},
    'Scale':      {'mrr': 129, 'churn_risk': 0.05},
    'Enterprise': {'mrr': 399, 'churn_risk': 0.02},   # sticky, high-touch customers
}

CHANNELS = ['Organic_Search', 'Paid_Ads', 'Referral', 'Outbound_Sales', 'Partner_Integration']
INDUSTRIES = ['E-commerce', 'FinTech', 'Healthcare', 'EdTech', 'Manufacturing', 'Agency']
CANCEL_REASONS = ['Too_Expensive', 'Missing_Features', 'Switched_Competitor', 'Poor_Support', 'No_Longer_Needed', None]

print("Simulating CloudSync subscription lifecycle...")

rows = []
customer_num = 1000

for _ in range(NUM_CUSTOMERS):
    customer_id = f'CS_{customer_num}'
    customer_num += 1

    # Weighted signup month -> more customers joined earlier (natural for cohort spread)
    signup_offset = np.random.choice(
        range(NUM_MONTHS - 2),
        p=np.array([1/(m+1)**0.5 for m in range(NUM_MONTHS - 2)]) /
          sum(1/(m+1)**0.5 for m in range(NUM_MONTHS - 2))
    )
    signup_date = START_DATE + timedelta(days=int(signup_offset * 30 + random.randint(0, 27)))

    plan = random.choices(list(PLAN_TIERS.keys()), weights=[45, 30, 18, 7])[0]
    channel = random.choices(CHANNELS, weights=[30, 25, 20, 15, 10])[0]
    industry = random.choice(INDUSTRIES)
    company_size = random.choice(['1-10', '11-50', '51-200', '201-500', '500+'])

    base_churn = PLAN_TIERS[plan]['churn_risk']
    mrr = PLAN_TIERS[plan]['mrr']

    is_active = True
    current_month = 0
    cancel_reason = None
    plan_history = plan

    while is_active and (signup_offset + current_month) < NUM_MONTHS:
        billing_date = signup_date + timedelta(days=30 * current_month)

        # Occasional upgrade after month 3 (happy customers expanding)
        if current_month == 3 and plan != 'Enterprise' and random.random() < 0.12:
            tiers = list(PLAN_TIERS.keys())
            idx = tiers.index(plan_history)
            plan_history = tiers[min(idx + 1, len(tiers) - 1)]
            mrr = PLAN_TIERS[plan_history]['mrr']

        rows.append({
            'customer_id': customer_id,
            'billing_date': billing_date.strftime('%Y-%m-%d'),
            'signup_date': signup_date.strftime('%Y-%m-%d'),
            'plan_tier': plan_history,
            'mrr_usd': mrr,
            'acquisition_channel': channel,
            'industry': industry,
            'company_size': company_size,
            'event_type': 'renewal' if current_month > 0 else 'new_signup',
            'cancellation_reason': None
        })

        # Determine churn — risk grows slightly over time (fatigue), but drops after month 6 (loyal core)
        month_factor = 1.3 if current_month < 3 else (1.0 if current_month < 6 else 0.6)
        churn_prob = base_churn * month_factor

        if random.random() < churn_prob:
            is_active = False
            cancel_reason = random.choices(
                CANCEL_REASONS,
                weights=[30, 25, 20, 15, 10, 0]
            )[0]
            rows.append({
                'customer_id': customer_id,
                'billing_date': (billing_date + timedelta(days=30)).strftime('%Y-%m-%d'),
                'signup_date': signup_date.strftime('%Y-%m-%d'),
                'plan_tier': plan_history,
                'mrr_usd': 0,
                'acquisition_channel': channel,
                'industry': industry,
                'company_size': company_size,
                'event_type': 'cancellation',
                'cancellation_reason': cancel_reason
            })

        current_month += 1

df = pd.DataFrame(rows)
df = df.sample(frac=1, random_state=7).reset_index(drop=True)  # shuffle like a real export

df.to_csv('cloudsync_subscriptions.csv', index=False)
print(f"✅ cloudsync_subscriptions.csv created — {len(df)} rows, {NUM_CUSTOMERS} customers")
print(df.head(10))
df = pd.read_csv('cloudsync_subscriptions.csv')
df.info()
df['event_type'].value_counts()
from google.colab import files
files.download('cloudsync_subscriptions.csv')
# Out:
# Simulating CloudSync subscription lifecycle...
# ✅ cloudsync_subscriptions.csv created — 19422 rows, 2500 customers
#   customer_id billing_date signup_date   plan_tier  mrr_usd  \
# 0     CS_2363   2023-03-24  2023-02-22       Scale      129
# 1     CS_1564   2023-03-02  2023-01-01     Starter       15
# 2     CS_2215   2024-02-28  2023-10-01     Starter       15
# 3     CS_2261   2024-03-29  2023-01-04     Starter       15
# 4     CS_2525   2023-12-17  2023-12-17     Starter       15
# 5     CS_3382   2023-05-13  2023-05-13     Starter       15
# 6     CS_2113   2023-02-25  2023-01-26  Enterprise      399
# 7     CS_2879   2024-03-04  2024-02-03     Starter        0
# 8     CS_2768   2024-05-02  2023-09-05      Growth       49
# 9     CS_3216   2024-02-14  2023-08-18       Scale      129
#
#    acquisition_channel    industry company_size    event_type  \
# 0             Paid_Ads     FinTech        11-50       renewal
# 1             Referral     FinTech         500+       renewal
# 2       Organic_Search  Healthcare        11-50       renewal
# 3  Partner_Integration  E-commerce       51-200       renewal
# 4             Paid_Ads  Healthcare         500+    new_signup
# 5             Referral  E-commerce        11-50    new_signup
# 6       Organic_Search      Agency      201-500       renewal
# 7             Paid_Ads     FinTech       51-200  cancellation
# 8       Outbound_Sales     FinTech        11-50       renewal
# 9       Outbound_Sales  Healthcare         1-10       renewal
#
#   cancellation_reason
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# 5                None
# 6                None
# 7    Missing_Features
# 8                None
# 9                None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          19422 non-null  object
#  1   billing_date         19422 non-null  object
#  2   signup_date          19422 non-null  object
#  3   plan_tier            19422 non-null  object
#  4   mrr_usd              19422 non-null  int64
#  5   acquisition_channel  19422 non-null  object
#  6   industry             19422 non-null  object
#  7   company_size         19422 non-null  object
#  8   event_type           19422 non-null  object
#  9   cancellation_reason  1546 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 1.5+ MB

# %%
import pandas as pd
import numpy as np
import datetime as dt
pd.set_option('display.max_rows' ,None)
pd.set_option('display.max_columns' ,None)
df=pd.read_csv("cloudsync_subscriptions.csv")
df.info()
df.describe()
df.head()
df.columns
df.columns.nunique()
df.isna().sum()
df["customer_id"].nunique()
len(df["customer_id"])
df["company_size"].idxmax()
df["billing_date"].head()
df["billing_date"]=pd.to_datetime(df["billing_date"])
df["billing_date"].head()
df["billing_day"]=df["billing_date"].dt.day
df["billing_month"]=df["billing_date"].dt.month
df["billing_year"]=df["billing_date"].dt.year
df["billing day_name"]=df["billing_date"].dt.day_name()
df["billing day_name"].unique()
df["billing_year"].unique()
df["billing_month"].nunique()
missing_percent = (df.isna().sum() / len(df))*100
missing_percent
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          19422 non-null  object
#  1   billing_date         19422 non-null  object
#  2   signup_date          19422 non-null  object
#  3   plan_tier            19422 non-null  object
#  4   mrr_usd              19422 non-null  int64
#  5   acquisition_channel  19422 non-null  object
#  6   industry             19422 non-null  object
#  7   company_size         19422 non-null  object
#  8   event_type           19422 non-null  object
#  9   cancellation_reason  1546 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 1.5+ MB
# customer_id             0.000000
# billing_date            0.000000
# signup_date             0.000000
# plan_tier               0.000000
# mrr_usd                 0.000000
# acquisition_channel     0.000000
# industry                0.000000
# company_size            0.000000
# event_type              0.000000
# cancellation_reason    92.039955
# billing_day             0.000000
# billing_month           0.000000
# billing_year            0.000000
# billing day_name        0.000000
# dtype: float64

# %%
df.head(5)
df.groupby("acquisition_channel")["mrr_usd"].sum()
df.groupby("billing_month")["mrr_usd"].sum()
df.tail(2)
df["cancellation_reason"].dropna()
# Out:
# 7           Missing_Features
# 16       Switched_Competitor
# 21             Too_Expensive
# 23          No_Longer_Needed
# 33          Missing_Features
# 77          Missing_Features
# 100         Missing_Features
# 127             Poor_Support
# 129             Poor_Support
# 133            Too_Expensive
# 135         Missing_Features
# 173         No_Longer_Needed
# 184         No_Longer_Needed
# 186            Too_Expensive
# 187         Missing_Features
# 194            Too_Expensive
# 211      Switched_Competitor
# 215            Too_Expensive
# 228            Too_Expensive
# 232         Missing_Features
# 235         Missing_Features
# 243            Too_Expensive
# 264            Too_Expensive
# 265         Missing_Features
# 273            Too_Expensive
# 298         Missing_Features
# 303            Too_Expensive
# 314         Missing_Features
# 316            Too_Expensive
# 320      Switched_Competitor
# 342      Switched_Competitor
# 350      Switched_Competitor
# 363         Missing_Features
# 366             Poor_Support
# 380         Missing_Features
# 383      Switched_Competitor
# 396             Poor_Support
# 411         Missing_Features
# 439      Switched_Competitor
# 441            Too_Expensive
# 443         Missing_Features
# 449      Switched_Competitor
# 463      Switched_Competitor
# 474         Missing_Features
# 502      Switched_Competitor
# 515             Poor_Support
# 523             Poor_Support
# 539             Poor_Support
# 575             Poor_Support
# 586         Missing_Features
# 589             Poor_Support
# 593             Poor_Support
# 621      Switched_Competitor
# 629            Too_Expensive
# 648         Missing_Features
# 661         Missing_Features
# 690      Switched_Competitor
# 691            Too_Expensive
# 692            Too_Expensive
# 706         Missing_Features
# 714            Too_Expensive
# 735            Too_Expensive
# 740      Switched_Competitor
# 744      Switched_Competitor
# 782             Poor_Support
# 794            Too_Expensive
# 817         No_Longer_Needed
# 840            Too_Expensive
# 843            Too_Expensive
# 846         Missing_Features
# 849         No_Longer_Needed
# 851      Switched_Competitor
# 856            Too_Expensive
# 864         No_Longer_Needed
# 868            Too_Expensive
# 890         No_Longer_Needed
# 894         Missing_Features
# 915         Missing_Features
# 947      Switched_Competitor
# 952      Switched_Competitor
# 954      Switched_Competitor
# 955             Poor_Support
# 973            Too_Expensive
# 982         No_Longer_Needed
# 991            Too_Expensive
# 1024            Poor_Support
# 1036           Too_Expensive
# 1040     Switched_Competitor
# 1042     Switched_Competitor
# 1049        Missing_Features
# 1053           Too_Expensive
# 1065        Missing_Features
# 1100            Poor_Support
# 1110     Switched_Competitor
# 1128           Too_Expensive
# 1131     Switched_Competitor
# 1144            Poor_Support
# 1149           Too_Expensive
# 1150        Missing_Features
# 1159            Poor_Support
# 1161           Too_Expensive
# 1167        No_Longer_Needed
# 1179     Switched_Competitor
# 1186     Switched_Competitor
# 1193            Poor_Support
# 1196           Too_Expensive
# 1201        Missing_Features
# 1206           Too_Expensive
# 1209           Too_Expensive
# 1229     Switched_Competitor
# 1245        Missing_Features
# 1248           Too_Expensive
# 1289           Too_Expensive
# 1290     Switched_Competitor
# 1296            Poor_Support
# 1308           Too_Expensive
# 1312           Too_Expensive
# 1326           Too_Expensive
# 1350        Missing_Features
# 1367        Missing_Features
# 1387           Too_Expensive
# 1401        Missing_Features
# 1410           Too_Expensive
# 1430           Too_Expensive
# 1437        No_Longer_Needed
# 1458           Too_Expensive
# 1470        Missing_Features
# 1483           Too_Expensive
# 1503            Poor_Support
# 1504        Missing_Features
# 1526     Switched_Competitor
# 1532           Too_Expensive
# 1539        Missing_Features
# 1547           Too_Expensive
# 1554        Missing_Features
# 1556        Missing_Features
# 1560           Too_Expensive
# 1565           Too_Expensive
# 1586        Missing_Features
# 1605     Switched_Competitor
# 1625     Switched_Competitor
# 1626        Missing_Features
# 1632        Missing_Features
# 1649     Switched_Competitor
# 1669           Too_Expensive
# 1676        Missing_Features
# 1685        Missing_Features
# 1690        Missing_Features
# 1703           Too_Expensive
# 1716        Missing_Features
# 1726        No_Longer_Needed
# 1753        Missing_Features
# 1757        No_Longer_Needed
# 1764     Switched_Competitor
# 1779           Too_Expensive
# 1782     Switched_Competitor
# 1799        No_Longer_Needed
# 1803           Too_Expensive
# 1807        Missing_Features
# 1817        Missing_Features
# 1828           Too_Expensive
# 1832        Missing_Features
# 1836        Missing_Features
# 1838        Missing_Features
# 1875        No_Longer_Needed
# 1900     Switched_Competitor
# 1935        Missing_Features
# 1937     Switched_Competitor
# 1944           Too_Expensive
# 1952     Switched_Competitor
# 1972        Missing_Features
# 1992        Missing_Features
# 2047        Missing_Features
# 2052     Switched_Competitor
# 2056     Switched_Competitor
# 2073        Missing_Features
# 2102           Too_Expensive
# 2125     Switched_Competitor
# 2129            Poor_Support
# 2139            Poor_Support
# 2160           Too_Expensive
# 2174     Switched_Competitor
# 2175           Too_Expensive
# 2180     Switched_Competitor
# 2210           Too_Expensive
# 2238        Missing_Features
# 2239        Missing_Features
# 2260           Too_Expensive
# 2274           Too_Expensive
# 2287           Too_Expensive
# 2291           Too_Expensive
# 2298           Too_Expensive
# 2321        Missing_Features
# 2324        Missing_Features
# 2363        Missing_Features
# 2380        Missing_Features
# 2394        No_Longer_Needed
# 2414        No_Longer_Needed
# 2439     Switched_Competitor
# 2476     Switched_Competitor
# 2482        Missing_Features
# 2490           Too_Expensive
# 2497            Poor_Support
# 2499        No_Longer_Needed
# 2500            Poor_Support
# 2518            Poor_Support
# 2523        No_Longer_Needed
# 2538     Switched_Competitor
# 2565     Switched_Competitor
# 2589        Missing_Features
# 2592     Switched_Competitor
# 2601        No_Longer_Needed
# 2609            Poor_Support
# 2617        Missing_Features
# 2619           Too_Expensive
# 2624           Too_Expensive
# 2636           Too_Expensive
# 2639     Switched_Competitor
# 2688     Switched_Competitor
# 2700        No_Longer_Needed
# 2705            Poor_Support
# 2706     Switched_Competitor
# 2714           Too_Expensive
# 2740     Switched_Competitor
# 2850     Switched_Competitor
# 2855           Too_Expensive
# 2871     Switched_Competitor
# 2886     Switched_Competitor
# 2888        No_Longer_Needed
# 2898           Too_Expensive
# 2909        Missing_Features
# 2910           Too_Expensive
# 2924        Missing_Features
# 2935           Too_Expensive
# 2943            Poor_Support
# 2948            Poor_Support
# 2957     Switched_Competitor
# 2977           Too_Expensive
# 2980           Too_Expensive
# 2985     Switched_Competitor
# 3002            Poor_Support
# 3003     Switched_Competitor
# 3048     Switched_Competitor
# 3058           Too_Expensive
# 3112           Too_Expensive
# 3114           Too_Expensive
# 3122        Missing_Features
# 3123        Missing_Features
# 3131            Poor_Support
# 3174            Poor_Support
# 3184           Too_Expensive
# 3205           Too_Expensive
# 3218     Switched_Competitor
# 3234            Poor_Support
# 3247        No_Longer_Needed
# 3249     Switched_Competitor
# 3265            Poor_Support
# 3327           Too_Expensive
# 3347            Poor_Support
# 3365        Missing_Features
# 3367     Switched_Competitor
# 3375           Too_Expensive
# 3381        Missing_Features
# 3386        Missing_Features
# 3455        Missing_Features
# 3462           Too_Expensive
# 3483            Poor_Support
# 3494        Missing_Features
# 3500     Switched_Competitor
# 3503     Switched_Competitor
# 3526           Too_Expensive
# 3556     Switched_Competitor
# 3573     Switched_Competitor
# 3576            Poor_Support
# 3601        No_Longer_Needed
# 3605     Switched_Competitor
# 3614        No_Longer_Needed
# 3621           Too_Expensive
# 3639           Too_Expensive
# 3641        Missing_Features
# 3665           Too_Expensive
# 3672           Too_Expensive
# 3676        No_Longer_Needed
# 3691           Too_Expensive
# 3698        Missing_Features
# 3708           Too_Expensive
# 3711            Poor_Support
# 3718     Switched_Competitor
# 3740     Switched_Competitor
# 3744        No_Longer_Needed
# 3747            Poor_Support
# 3753     Switched_Competitor
# 3762           Too_Expensive
# 3767        No_Longer_Needed
# 3768     Switched_Competitor
# 3778        Missing_Features
# 3779           Too_Expensive
# 3790           Too_Expensive
# 3792           Too_Expensive
# 3809        No_Longer_Needed
# 3816        No_Longer_Needed
# 3819           Too_Expensive
# 3827     Switched_Competitor
# 3830           Too_Expensive
# 3855           Too_Expensive
# 3887        Missing_Features
# 3892            Poor_Support
# 3949            Poor_Support
# 3952     Switched_Competitor
# 3961     Switched_Competitor
# 3968        Missing_Features
# 3975        Missing_Features
# 3978           Too_Expensive
# 3995            Poor_Support
# 3997     Switched_Competitor
# 4030        Missing_Features
# 4031           Too_Expensive
# 4038        Missing_Features
# 4040        No_Longer_Needed
# 4046     Switched_Competitor
# 4047     Switched_Competitor
# 4081            Poor_Support
# 4087     Switched_Competitor
# 4091            Poor_Support
# 4095           Too_Expensive
# 4097     Switched_Competitor
# 4100        Missing_Features
# 4116        No_Longer_Needed
# 4126            Poor_Support
# 4169        Missing_Features
# 4191        Missing_Features
# 4200     Switched_Competitor
# 4208     Switched_Competitor
# 4247     Switched_Competitor
# 4248        Missing_Features
# 4251            Poor_Support
# 4257           Too_Expensive
# 4266           Too_Expensive
# 4267           Too_Expensive
# 4298           Too_Expensive
# 4331        No_Longer_Needed
# 4335           Too_Expensive
# 4345            Poor_Support
# 4352     Switched_Competitor
# 4360        Missing_Features
# 4372            Poor_Support
# 4380        No_Longer_Needed
# 4385     Switched_Competitor
# 4393        Missing_Features
# 4397     Switched_Competitor
# 4400     Switched_Competitor
# 4407            Poor_Support
# 4412     Switched_Competitor
# 4415     Switched_Competitor
# 4445     Switched_Competitor
# 4446     Switched_Competitor
# 4464     Switched_Competitor
# 4477        No_Longer_Needed
# 4486        No_Longer_Needed
# 4492        Missing_Features
# 4504        Missing_Features
# 4518        No_Longer_Needed
# 4521           Too_Expensive
# 4526     Switched_Competitor
# 4534        No_Longer_Needed
# 4539           Too_Expensive
# 4541        Missing_Features
# 4559            Poor_Support
# 4565     Switched_Competitor
# 4568     Switched_Competitor
# 4583           Too_Expensive
# 4588            Poor_Support
# 4607        No_Longer_Needed
# 4616           Too_Expensive
# 4634     Switched_Competitor
# 4644        Missing_Features
# 4655        Missing_Features
# 4659        Missing_Features
# 4666     Switched_Competitor
# 4673            Poor_Support
# 4679        Missing_Features
# 4680           Too_Expensive
# 4695     Switched_Competitor
# 4717     Switched_Competitor
# 4720           Too_Expensive
# 4784        Missing_Features
# 4786           Too_Expensive
# 4794     Switched_Competitor
# 4795     Switched_Competitor
# 4800        Missing_Features
# 4802           Too_Expensive
# 4805            Poor_Support
# 4809        Missing_Features
# 4815        Missing_Features
# 4840           Too_Expensive
# 4856        No_Longer_Needed
# 4872           Too_Expensive
# 4880            Poor_Support
# 4960            Poor_Support
# 4961     Switched_Competitor
# 4995        Missing_Features
# 5000     Switched_Competitor
# 5012        No_Longer_Needed
# 5015        No_Longer_Needed
# 5073        Missing_Features
# 5074        Missing_Features
# 5111     Switched_Competitor
# 5125           Too_Expensive
# 5137            Poor_Support
# 5138     Switched_Competitor
# 5141        Missing_Features
# 5142            Poor_Support
# 5153           Too_Expensive
# 5163        No_Longer_Needed
# 5171           Too_Expensive
# 5176        Missing_Features
# 5185            Poor_Support
# 5212        Missing_Features
# 5218           Too_Expensive
# 5230        Missing_Features
# 5232        No_Longer_Needed
# 5249           Too_Expensive
# 5259           Too_Expensive
# 5262     Switched_Competitor
# 5263           Too_Expensive
# 5277        Missing_Features
# 5299        Missing_Features
# 5313     Switched_Competitor
# 5334           Too_Expensive
# 5345           Too_Expensive
# 5356     Switched_Competitor
# 5357            Poor_Support
# 5370     Switched_Competitor
# 5385        Missing_Features
# 5391           Too_Expensive
# 5395            Poor_Support
# 5399           Too_Expensive
# 5400           Too_Expensive
# 5418           Too_Expensive
# 5426        Missing_Features
# 5431           Too_Expensive
# 5434        Missing_Features
# 5442     Switched_Competitor
# 5470     Switched_Competitor
# 5484        Missing_Features
# 5525        Missing_Features
# 5534        Missing_Features
# 5543     Switched_Competitor
# 5555            Poor_Support
# 5558           Too_Expensive
# 5562           Too_Expensive
# 5565           Too_Expensive
# 5580     Switched_Competitor
# 5588           Too_Expensive
# 5607            Poor_Support
# 5627           Too_Expensive
# 5638           Too_Expensive
# 5644            Poor_Support
# 5647            Poor_Support
# 5666        Missing_Features
# 5693        No_Longer_Needed
# 5713           Too_Expensive
# 5734           Too_Expensive
# 5749           Too_Expensive
# 5766           Too_Expensive
# 5770        Missing_Features
# 5777        Missing_Features
# 5786        Missing_Features
# 5816           Too_Expensive
# 5823           Too_Expensive
# 5824        No_Longer_Needed
# 5829           Too_Expensive
# 5849           Too_Expensive
# 5900        No_Longer_Needed
# 5902            Poor_Support
# 5905     Switched_Competitor
# 5914     Switched_Competitor
# 5936        Missing_Features
# 5979     Switched_Competitor
# 5985        Missing_Features
# 5995           Too_Expensive
# 5997     Switched_Competitor
# 6000        No_Longer_Needed
# 6002           Too_Expensive
# 6007     Switched_Competitor
# 6016        Missing_Features
# 6031        Missing_Features
# 6035        Missing_Features
# 6043        No_Longer_Needed
# 6050     Switched_Competitor
# 6056            Poor_Support
# 6059        Missing_Features
# 6061           Too_Expensive
# 6073        Missing_Features
# 6078     Switched_Competitor
# 6079        Missing_Features
# 6092           Too_Expensive
# 6095            Poor_Support
# 6102        No_Longer_Needed
# 6148           Too_Expensive
# 6180        Missing_Features
# 6185     Switched_Competitor
# 6209        Missing_Features
# 6220        Missing_Features
# 6227            Poor_Support
# 6229     Switched_Competitor
# 6232           Too_Expensive
# 6243        No_Longer_Needed
# 6258        Missing_Features
# 6259           Too_Expensive
# 6279        Missing_Features
# 6293           Too_Expensive
# 6294            Poor_Support
# 6301           Too_Expensive
# 6323           Too_Expensive
# 6343        Missing_Features
# 6344        Missing_Features
# 6359           Too_Expensive
# 6367     Switched_Competitor
# 6371           Too_Expensive
# 6400            Poor_Support
# 6402     Switched_Competitor
# 6413        Missing_Features
# 6432        No_Longer_Needed
# 6435            Poor_Support
# 6437            Poor_Support
# 6453            Poor_Support
# 6456        No_Longer_Needed
# 6487           Too_Expensive
# 6499        Missing_Features
# 6502            Poor_Support
# 6535        Missing_Features
# 6542            Poor_Support
# 6578           Too_Expensive
# 6586        No_Longer_Needed
# 6587        Missing_Features
# 6590            Poor_Support
# 6592            Poor_Support
# 6597        No_Longer_Needed
# 6598     Switched_Competitor
# 6611        Missing_Features
# 6613           Too_Expensive
# 6619        Missing_Features
# 6621     Switched_Competitor
# 6630     Switched_Competitor
# 6649            Poor_Support
# 6669     Switched_Competitor
# 6696            Poor_Support
# 6697        Missing_Features
# 6736           Too_Expensive
# 6751           Too_Expensive
# 6765     Switched_Competitor
# 6769        No_Longer_Needed
# 6770           Too_Expensive
# 6784     Switched_Competitor
# 6785        Missing_Features
# 6794            Poor_Support
# 6867        Missing_Features
# 6889        Missing_Features
# 6897            Poor_Support
# 6901           Too_Expensive
# 6905     Switched_Competitor
# 6910            Poor_Support
# 6924        No_Longer_Needed
# 6934        Missing_Features
# 6949        No_Longer_Needed
# 6957     Switched_Competitor
# 6962     Switched_Competitor
# 6970     Switched_Competitor
# 6975            Poor_Support
# 6991        Missing_Features
# 6993           Too_Expensive
# 6997           Too_Expensive
# 7018            Poor_Support
# 7024           Too_Expensive
# 7052     Switched_Competitor
# 7065        Missing_Features
# 7074        Missing_Features
# 7083        Missing_Features
# 7096        Missing_Features
# 7103        Missing_Features
# 7108     Switched_Competitor
# 7124     Switched_Competitor
# 7153            Poor_Support
# 7160            Poor_Support
# 7162           Too_Expensive
# 7179        No_Longer_Needed
# 7180     Switched_Competitor
# 7187     Switched_Competitor
# 7198        Missing_Features
# 7203           Too_Expensive
# 7220        Missing_Features
# 7226           Too_Expensive
# 7233           Too_Expensive
# 7258            Poor_Support
# 7262        Missing_Features
# 7290           Too_Expensive
# 7335           Too_Expensive
# 7350        Missing_Features
# 7352           Too_Expensive
# 7360            Poor_Support
# 7362           Too_Expensive
# 7373           Too_Expensive
# 7393           Too_Expensive
# 7414        Missing_Features
# 7417     Switched_Competitor
# 7470            Poor_Support
# 7472        Missing_Features
# 7494        Missing_Features
# 7497           Too_Expensive
# 7521        Missing_Features
# 7532        Missing_Features
# 7533        Missing_Features
# 7547     Switched_Competitor
# 7555           Too_Expensive
# 7562        Missing_Features
# 7595           Too_Expensive
# 7604        No_Longer_Needed
# 7605           Too_Expensive
# 7636           Too_Expensive
# 7659     Switched_Competitor
# 7667        Missing_Features
# 7681        No_Longer_Needed
# 7694     Switched_Competitor
# 7700        No_Longer_Needed
# 7702     Switched_Competitor
# 7719        No_Longer_Needed
# 7748        Missing_Features
# 7755            Poor_Support
# 7773           Too_Expensive
# 7777            Poor_Support
# 7796            Poor_Support
# 7801        Missing_Features
# 7806     Switched_Competitor
# 7816           Too_Expensive
# 7817           Too_Expensive
# 7821            Poor_Support
# 7849           Too_Expensive
# 7857           Too_Expensive
# 7868        Missing_Features
# 7871     Switched_Competitor
# 7872           Too_Expensive
# 7879           Too_Expensive
# 7880        No_Longer_Needed
# 7884     Switched_Competitor
# 7889           Too_Expensive
# 7931        Missing_Features
# 7932           Too_Expensive
# 7955     Switched_Competitor
# 7956        Missing_Features
# 7961     Switched_Competitor
# 7974           Too_Expensive
# 7995     Switched_Competitor
# 8006        Missing_Features
# 8011           Too_Expensive
# 8013           Too_Expensive
# 8017     Switched_Competitor
# 8027     Switched_Competitor
# 8046     Switched_Competitor
# 8050     Switched_Competitor
# 8074        Missing_Features
# 8080            Poor_Support
# 8081           Too_Expensive
# 8085           Too_Expensive
# 8096        Missing_Features
# 8104     Switched_Competitor
# 8108        Missing_Features
# 8121           Too_Expensive
# 8126           Too_Expensive
# 8129        Missing_Features
# 8161        No_Longer_Needed
# 8167            Poor_Support
# 8198            Poor_Support
# 8200            Poor_Support
# 8210        Missing_Features
# 8211           Too_Expensive
# 8228           Too_Expensive
# 8234            Poor_Support
# 8256           Too_Expensive
# 8269            Poor_Support
# 8278     Switched_Competitor
# 8281        No_Longer_Needed
# 8285           Too_Expensive
# 8286        Missing_Features
# 8293           Too_Expensive
# 8299     Switched_Competitor
# 8321           Too_Expensive
# 8338        Missing_Features
# 8339           Too_Expensive
# 8351           Too_Expensive
# 8399     Switched_Competitor
# 8404     Switched_Competitor
# 8412           Too_Expensive
# 8429           Too_Expensive
# 8431            Poor_Support
# 8460        Missing_Features
# 8483        Missing_Features
# 8487        Missing_Features
# 8490        Missing_Features
# 8498     Switched_Competitor
# 8505           Too_Expensive
# 8511     Switched_Competitor
# 8516        Missing_Features
# 8550           Too_Expensive
# 8551        No_Longer_Needed
# 8553        No_Longer_Needed
# 8561     Switched_Competitor
# 8562           Too_Expensive
# 8574     Switched_Competitor
# 8595            Poor_Support
# 8611        No_Longer_Needed
# 8657            Poor_Support
# 8660        Missing_Features
# 8696        Missing_Features
# 8704        Missing_Features
# 8714     Switched_Competitor
# 8716        No_Longer_Needed
# 8724        No_Longer_Needed
# 8773            Poor_Support
# 8789     Switched_Competitor
# 8793        No_Longer_Needed
# 8802           Too_Expensive
# 8830            Poor_Support
# 8841        Missing_Features
# 8851     Switched_Competitor
# 8852           Too_Expensive
# 8856            Poor_Support
# 8863           Too_Expensive
# 8869        No_Longer_Needed
# 8903     Switched_Competitor
# 8941           Too_Expensive
# 8946            Poor_Support
# 8955            Poor_Support
# 8994            Poor_Support
# 8999        Missing_Features
# 9013           Too_Expensive
# 9032     Switched_Competitor
# 9033           Too_Expensive
# 9038        No_Longer_Needed
# 9043           Too_Expensive
# 9045            Poor_Support
# 9066            Poor_Support
# 9080           Too_Expensive
# 9084     Switched_Competitor
# 9112     Switched_Competitor
# 9116            Poor_Support
# 9125        No_Longer_Needed
# 9128        Missing_Features
# 9140        Missing_Features
# 9143            Poor_Support
# 9148           Too_Expensive
# 9174            Poor_Support
# 9198        Missing_Features
# 9211        No_Longer_Needed
# 9215        No_Longer_Needed
# 9216           Too_Expensive
# 9245           Too_Expensive
# 9246     Switched_Competitor
# 9275           Too_Expensive
# 9276        Missing_Features
# 9297     Switched_Competitor
# 9301        No_Longer_Needed
# 9305           Too_Expensive
# 9307     Switched_Competitor
# 9317     Switched_Competitor
# 9319     Switched_Competitor
# 9336           Too_Expensive
# 9343        Missing_Features
# 9347        Missing_Features
# 9368           Too_Expensive
# 9373     Switched_Competitor
# 9396        Missing_Features
# 9401           Too_Expensive
# 9404        Missing_Features
# 9407     Switched_Competitor
# 9447            Poor_Support
# 9452        Missing_Features
# 9454           Too_Expensive
# 9465     Switched_Competitor
# 9504           Too_Expensive
# 9519        Missing_Features
# 9543           Too_Expensive
# 9567     Switched_Competitor
# 9584            Poor_Support
# 9607        Missing_Features
# 9621        Missing_Features
# 9622        Missing_Features
# 9630        Missing_Features
# 9654        Missing_Features
# 9679        Missing_Features
# 9692           Too_Expensive
# 9694     Switched_Competitor
# 9695           Too_Expensive
# 9714            Poor_Support
# 9722           Too_Expensive
# 9726           Too_Expensive
# 9744     Switched_Competitor
# 9752        Missing_Features
# 9756        Missing_Features
# 9758        Missing_Features
# 9763           Too_Expensive
# 9765        Missing_Features
# 9778        Missing_Features
# 9789           Too_Expensive
# 9794            Poor_Support
# 9797        No_Longer_Needed
# 9824        Missing_Features
# 9831        Missing_Features
# 9832            Poor_Support
# 9843            Poor_Support
# 9885           Too_Expensive
# 9904            Poor_Support
# 9913           Too_Expensive
# 9915     Switched_Competitor
# 9930        Missing_Features
# 9942        Missing_Features
# 9943        Missing_Features
# 9949        Missing_Features
# 9966           Too_Expensive
# 9972     Switched_Competitor
# 9979           Too_Expensive
# 9988        Missing_Features
# 9989        Missing_Features
# 10009          Too_Expensive
# 10018       Missing_Features
# 10030    Switched_Competitor
# 10046       Missing_Features
# 10056          Too_Expensive
# 10076       Missing_Features
# 10077           Poor_Support
# 10110    Switched_Competitor
# 10122          Too_Expensive
# 10132          Too_Expensive
# 10135    Switched_Competitor
# 10172          Too_Expensive
# 10195    Switched_Competitor
# 10282    Switched_Competitor
# 10294           Poor_Support
# 10308       No_Longer_Needed
# 10333          Too_Expensive
# 10337          Too_Expensive
# 10348    Switched_Competitor
# 10360          Too_Expensive
# 10401       Missing_Features
# 10405       Missing_Features
# 10417       No_Longer_Needed
# 10419           Poor_Support
# 10428           Poor_Support
# 10445           Poor_Support
# 10480       Missing_Features
# 10512    Switched_Competitor
# 10516          Too_Expensive
# 10523       No_Longer_Needed
# 10547          Too_Expensive
# 10554          Too_Expensive
# 10563          Too_Expensive
# 10566       Missing_Features
# 10588    Switched_Competitor
# 10611       Missing_Features
# 10620       Missing_Features
# 10624    Switched_Competitor
# 10636       Missing_Features
# 10637    Switched_Competitor
# 10645           Poor_Support
# 10656          Too_Expensive
# 10691    Switched_Competitor
# 10726       Missing_Features
# 10750          Too_Expensive
# 10781       No_Longer_Needed
# 10795    Switched_Competitor
# 10815    Switched_Competitor
# 10837       Missing_Features
# 10883       Missing_Features
# 10886       Missing_Features
# 10912          Too_Expensive
# 10916          Too_Expensive
# 10931       Missing_Features
# 10943          Too_Expensive
# 10953    Switched_Competitor
# 10954          Too_Expensive
# 10956          Too_Expensive
# 10964    Switched_Competitor
# 10979    Switched_Competitor
# 10984    Switched_Competitor
# 10991    Switched_Competitor
# 10996    Switched_Competitor
# 11038          Too_Expensive
# 11051           Poor_Support
# 11068          Too_Expensive
# 11093           Poor_Support
# 11124       Missing_Features
# 11128       Missing_Features
# 11131          Too_Expensive
# 11135       No_Longer_Needed
# 11161          Too_Expensive
# 11166       Missing_Features
# 11187       No_Longer_Needed
# 11195       Missing_Features
# 11204       No_Longer_Needed
# 11216       No_Longer_Needed
# 11218    Switched_Competitor
# 11221    Switched_Competitor
# 11223       Missing_Features
# 11232    Switched_Competitor
# 11235          Too_Expensive
# 11260          Too_Expensive
# 11261          Too_Expensive
# 11274    Switched_Competitor
# 11280       No_Longer_Needed
# 11305          Too_Expensive
# 11346       Missing_Features
# 11380    Switched_Competitor
# 11387          Too_Expensive
# 11392           Poor_Support
# 11394          Too_Expensive
# 11401          Too_Expensive
# 11416    Switched_Competitor
# 11448          Too_Expensive
# 11453    Switched_Competitor
# 11459           Poor_Support
# 11466          Too_Expensive
# 11488          Too_Expensive
# 11511          Too_Expensive
# 11530    Switched_Competitor
# 11562       Missing_Features
# 11571    Switched_Competitor
# 11574           Poor_Support
# 11592    Switched_Competitor
# 11614           Poor_Support
# 11635          Too_Expensive
# 11637    Switched_Competitor
# 11662       Missing_Features
# 11676       No_Longer_Needed
# 11689       No_Longer_Needed
# 11702    Switched_Competitor
# 11725    Switched_Competitor
# 11735       Missing_Features
# 11737          Too_Expensive
# 11769    Switched_Competitor
# 11779    Switched_Competitor
# 11792       No_Longer_Needed
# 11793       Missing_Features
# 11804       Missing_Features
# 11814          Too_Expensive
# 11822       Missing_Features
# 11830          Too_Expensive
# 11832    Switched_Competitor
# 11836       Missing_Features
# 11842       Missing_Features
# 11852          Too_Expensive
# 11853       Missing_Features
# 11858          Too_Expensive
# 11891       Missing_Features
# 11900       Missing_Features
# 11903       No_Longer_Needed
# 11925           Poor_Support
# 11944    Switched_Competitor
# 11948       No_Longer_Needed
# 11970       Missing_Features
# 11973    Switched_Competitor
# 11991       No_Longer_Needed
# 11994    Switched_Competitor
# 12067          Too_Expensive
# 12073          Too_Expensive
# 12084    Switched_Competitor
# 12116           Poor_Support
# 12119          Too_Expensive
# 12147       Missing_Features
# 12163       No_Longer_Needed
# 12182    Switched_Competitor
# 12183          Too_Expensive
# 12196       No_Longer_Needed
# 12203       Missing_Features
# 12218       Missing_Features
# 12221       Missing_Features
# 12245       Missing_Features
# 12248          Too_Expensive
# 12249          Too_Expensive
# 12261       Missing_Features
# 12264    Switched_Competitor
# 12281    Switched_Competitor
# 12310           Poor_Support
# 12328          Too_Expensive
# 12332    Switched_Competitor
# 12333    Switched_Competitor
# 12337          Too_Expensive
# 12338          Too_Expensive
# 12349       No_Longer_Needed
# 12351       Missing_Features
# 12358       Missing_Features
# 12375          Too_Expensive
# 12444    Switched_Competitor
# 12455    Switched_Competitor
# 12459    Switched_Competitor
# 12470       No_Longer_Needed
# 12489       Missing_Features
# 12496           Poor_Support
# 12501    Switched_Competitor
# 12528       No_Longer_Needed
# 12548       Missing_Features
# 12580          Too_Expensive
# 12588           Poor_Support
# 12596    Switched_Competitor
# 12606       Missing_Features
# 12608    Switched_Competitor
# 12611       Missing_Features
# 12613       Missing_Features
# 12623          Too_Expensive
# 12655       No_Longer_Needed
# 12665          Too_Expensive
# 12668       Missing_Features
# 12685           Poor_Support
# 12687          Too_Expensive
# 12695       No_Longer_Needed
# 12716       No_Longer_Needed
# 12723       Missing_Features
# 12726       Missing_Features
# 12733    Switched_Competitor
# 12769       Missing_Features
# 12787       No_Longer_Needed
# 12788          Too_Expensive
# 12794    Switched_Competitor
# 12795          Too_Expensive
# 12812       No_Longer_Needed
# 12815       Missing_Features
# 12832       Missing_Features
# 12839           Poor_Support
# 12873       Missing_Features
# 12886       No_Longer_Needed
# 12889       Missing_Features
# 12899    Switched_Competitor
# 12902       Missing_Features
# 12904       No_Longer_Needed
# 12934    Switched_Competitor
# 12948       Missing_Features
# 12954       Missing_Features
# 12973       Missing_Features
# 12984          Too_Expensive
# 12998          Too_Expensive
# 13005          Too_Expensive
# 13008       Missing_Features
# 13014          Too_Expensive
# 13020          Too_Expensive
# 13023       No_Longer_Needed
# 13049       Missing_Features
# 13050       No_Longer_Needed
# 13054    Switched_Competitor
# 13059       Missing_Features
# 13072       Missing_Features
# 13083       No_Longer_Needed
# 13116          Too_Expensive
# 13119       Missing_Features
# 13121          Too_Expensive
# 13130       No_Longer_Needed
# 13138    Switched_Competitor
# 13158          Too_Expensive
# 13183       Missing_Features
# 13187       No_Longer_Needed
# 13196       No_Longer_Needed
# 13199       No_Longer_Needed
# 13202       Missing_Features
# 13206          Too_Expensive
# 13210           Poor_Support
# 13223           Poor_Support
# 13238           Poor_Support
# 13246       Missing_Features
# 13272           Poor_Support
# 13277       No_Longer_Needed
# 13300    Switched_Competitor
# 13312           Poor_Support
# 13315       Missing_Features
# 13324    Switched_Competitor
# 13333       No_Longer_Needed
# 13338          Too_Expensive
# 13365       Missing_Features
# 13369          Too_Expensive
# 13376       Missing_Features
# 13379           Poor_Support
# 13387       Missing_Features
# 13388       No_Longer_Needed
# 13398          Too_Expensive
# 13419       No_Longer_Needed
# 13426          Too_Expensive
# 13427       No_Longer_Needed
# 13431          Too_Expensive
# 13438       Missing_Features
# 13449          Too_Expensive
# 13471    Switched_Competitor
# 13480          Too_Expensive
# 13482          Too_Expensive
# 13485    Switched_Competitor
# 13504    Switched_Competitor
# 13516           Poor_Support
# 13572       Missing_Features
# 13581          Too_Expensive
# 13583          Too_Expensive
# 13600          Too_Expensive
# 13623       No_Longer_Needed
# 13626       Missing_Features
# 13642          Too_Expensive
# 13655    Switched_Competitor
# 13657    Switched_Competitor
# 13680          Too_Expensive
# 13698          Too_Expensive
# 13705          Too_Expensive
# 13715       Missing_Features
# 13738    Switched_Competitor
# 13743    Switched_Competitor
# 13744       Missing_Features
# 13745          Too_Expensive
# 13812           Poor_Support
# 13821          Too_Expensive
# 13882       Missing_Features
# 13892          Too_Expensive
# 13925       No_Longer_Needed
# 13931           Poor_Support
# 13964       No_Longer_Needed
# 13974          Too_Expensive
# 13986       No_Longer_Needed
# 13999    Switched_Competitor
# 14010          Too_Expensive
# 14013       Missing_Features
# 14041       Missing_Features
# 14054       Missing_Features
# 14074           Poor_Support
# 14087          Too_Expensive
# 14109           Poor_Support
# 14111           Poor_Support
# 14114    Switched_Competitor
# 14124           Poor_Support
# 14125       Missing_Features
# 14128       No_Longer_Needed
# 14142       Missing_Features
# 14165          Too_Expensive
# 14173       Missing_Features
# 14175           Poor_Support
# 14180       No_Longer_Needed
# 14247       Missing_Features
# 14250           Poor_Support
# 14256    Switched_Competitor
# 14266       No_Longer_Needed
# 14272    Switched_Competitor
# 14276          Too_Expensive
# 14287       Missing_Features
# 14292    Switched_Competitor
# 14299    Switched_Competitor
# 14304    Switched_Competitor
# 14320       Missing_Features
# 14347          Too_Expensive
# 14361       No_Longer_Needed
# 14410          Too_Expensive
# 14414       Missing_Features
# 14423    Switched_Competitor
# 14430    Switched_Competitor
# 14435       Missing_Features
# 14441    Switched_Competitor
# 14444    Switched_Competitor
# 14452       No_Longer_Needed
# 14464       Missing_Features
# 14475           Poor_Support
# 14486       No_Longer_Needed
# 14497       No_Longer_Needed
# 14502       No_Longer_Needed
# 14511          Too_Expensive
# 14513       Missing_Features
# 14530       Missing_Features
# 14571           Poor_Support
# 14581          Too_Expensive
# 14595       Missing_Features
# 14599          Too_Expensive
# 14608          Too_Expensive
# 14614           Poor_Support
# 14618          Too_Expensive
# 14637       Missing_Features
# 14647           Poor_Support
# 14657       Missing_Features
# 14659    Switched_Competitor
# 14670       Missing_Features
# 14674       No_Longer_Needed
# 14682    Switched_Competitor
# 14720       No_Longer_Needed
# 14765    Switched_Competitor
# 14771       Missing_Features
# 14773          Too_Expensive
# 14801           Poor_Support
# 14811           Poor_Support
# 14812           Poor_Support
# 14824          Too_Expensive
# 14860          Too_Expensive
# 14865    Switched_Competitor
# 14870       Missing_Features
# 14875       Missing_Features
# 14882       No_Longer_Needed
# 14898    Switched_Competitor
# 14899       Missing_Features
# 14901    Switched_Competitor
# 14926           Poor_Support
# 14951       Missing_Features
# 14961    Switched_Competitor
# 14962           Poor_Support
# 14963           Poor_Support
# 14964          Too_Expensive
# 14981           Poor_Support
# 14999    Switched_Competitor
# 15045           Poor_Support
# 15056           Poor_Support
# 15064           Poor_Support
# 15118          Too_Expensive
# 15178    Switched_Competitor
# 15182       Missing_Features
# 15185    Switched_Competitor
# 15208           Poor_Support
# 15214       No_Longer_Needed
# 15224    Switched_Competitor
# 15257       Missing_Features
# 15259          Too_Expensive
# 15279       Missing_Features
# 15288    Switched_Competitor
# 15330           Poor_Support
# 15352          Too_Expensive
# 15393           Poor_Support
# 15403          Too_Expensive
# 15419           Poor_Support
# 15423    Switched_Competitor
# 15428          Too_Expensive
# 15443    Switched_Competitor
# 15449    Switched_Competitor
# 15455       Missing_Features
# 15478          Too_Expensive
# 15484          Too_Expensive
# 15498    Switched_Competitor
# 15513       Missing_Features
# 15523       No_Longer_Needed
# 15531       Missing_Features
# 15534           Poor_Support
# 15541          Too_Expensive
# 15547           Poor_Support
# 15565           Poor_Support
# 15581           Poor_Support
# 15585          Too_Expensive
# 15613    Switched_Competitor
# 15631          Too_Expensive
# 15637       No_Longer_Needed
# 15638       Missing_Features
# 15649       Missing_Features
# 15668       Missing_Features
# 15689          Too_Expensive
# 15695          Too_Expensive
# 15703           Poor_Support
# 15728       Missing_Features
# 15738          Too_Expensive
# 15743          Too_Expensive
# 15753          Too_Expensive
# 15761          Too_Expensive
# 15782       Missing_Features
# 15795    Switched_Competitor
# 15796       Missing_Features
# 15802           Poor_Support
# 15807       Missing_Features
# 15815    Switched_Competitor
# 15830           Poor_Support
# 15831           Poor_Support
# 15841    Switched_Competitor
# 15842          Too_Expensive
# 15852       Missing_Features
# 15895          Too_Expensive
# 15928       Missing_Features
# 15938          Too_Expensive
# 15952           Poor_Support
# 15957          Too_Expensive
# 15978          Too_Expensive
# 15989    Switched_Competitor
# 15995          Too_Expensive
# 16004           Poor_Support
# 16031           Poor_Support
# 16036          Too_Expensive
# 16042           Poor_Support
# 16049    Switched_Competitor
# 16061    Switched_Competitor
# 16089       No_Longer_Needed
# 16106       Missing_Features
# 16118          Too_Expensive
# 16129       Missing_Features
# 16134          Too_Expensive
# 16137          Too_Expensive
# 16144       No_Longer_Needed
# 16168          Too_Expensive
# 16170    Switched_Competitor
# 16181    Switched_Competitor
# 16193    Switched_Competitor
# 16200       Missing_Features
# 16226           Poor_Support
# 16240          Too_Expensive
# 16302       Missing_Features
# 16303       Missing_Features
# 16319    Switched_Competitor
# 16320    Switched_Competitor
# 16330    Switched_Competitor
# 16339    Switched_Competitor
# 16342       Missing_Features
# 16343    Switched_Competitor
# 16391          Too_Expensive
# 16393       Missing_Features
# 16394       Missing_Features
# 16403    Switched_Competitor
# 16413           Poor_Support
# 16414           Poor_Support
# 16431    Switched_Competitor
# 16468    Switched_Competitor
# 16478          Too_Expensive
# 16482          Too_Expensive
# 16492       No_Longer_Needed
# 16510          Too_Expensive
# 16517       Missing_Features
# 16520          Too_Expensive
# 16531           Poor_Support
# 16535          Too_Expensive
# 16545          Too_Expensive
# 16554    Switched_Competitor
# 16598           Poor_Support
# 16614          Too_Expensive
# 16626           Poor_Support
# 16630       Missing_Features
# 16632          Too_Expensive
# 16634          Too_Expensive
# 16638          Too_Expensive
# 16648       Missing_Features
# 16657          Too_Expensive
# 16661           Poor_Support
# 16662          Too_Expensive
# 16668       Missing_Features
# 16686       Missing_Features
# 16690       Missing_Features
# 16701       Missing_Features
# 16742          Too_Expensive
# 16797           Poor_Support
# 16799           Poor_Support
# 16831       Missing_Features
# 16856       No_Longer_Needed
# 16865    Switched_Competitor
# 16893       Missing_Features
# 16894          Too_Expensive
# 16896       Missing_Features
# 16932       Missing_Features
# 16942       Missing_Features
# 16943          Too_Expensive
# 16948           Poor_Support
# 16950       No_Longer_Needed
# 16958       No_Longer_Needed
# 17006       No_Longer_Needed
# 17012           Poor_Support
# 17016          Too_Expensive
# 17050    Switched_Competitor
# 17068          Too_Expensive
# 17087          Too_Expensive
# 17092          Too_Expensive
# 17118          Too_Expensive
# 17120          Too_Expensive
# 17154    Switched_Competitor
# 17155          Too_Expensive
# 17167       Missing_Features
# 17171          Too_Expensive
# 17175          Too_Expensive
# 17200       Missing_Features
# 17205          Too_Expensive
# 17221           Poor_Support
# 17223           Poor_Support
# 17224          Too_Expensive
# 17228    Switched_Competitor
# 17229    Switched_Competitor
# 17263           Poor_Support
# 17279       Missing_Features
# 17293       Missing_Features
# 17308    Switched_Competitor
# 17313    Switched_Competitor
# 17342    Switched_Competitor
# 17343       Missing_Features
# 17378          Too_Expensive
# 17393          Too_Expensive
# 17396    Switched_Competitor
# 17443       Missing_Features
# 17467          Too_Expensive
# 17475          Too_Expensive
# 17486       No_Longer_Needed
# 17516       No_Longer_Needed
# 17517           Poor_Support
# 17522    Switched_Competitor
# 17525          Too_Expensive
# 17531          Too_Expensive
# 17561    Switched_Competitor
# 17620          Too_Expensive
# 17623          Too_Expensive
# 17635       Missing_Features
# 17641       Missing_Features
# 17649       Missing_Features
# 17652    Switched_Competitor
# 17661           Poor_Support
# 17662       No_Longer_Needed
# 17687           Poor_Support
# 17688          Too_Expensive
# 17690       Missing_Features
# 17693       No_Longer_Needed
# 17706       Missing_Features
# 17722           Poor_Support
# 17723          Too_Expensive
# 17733    Switched_Competitor
# 17738       No_Longer_Needed
# 17746       Missing_Features
# 17767           Poor_Support
# 17768          Too_Expensive
# 17779    Switched_Competitor
# 17781          Too_Expensive
# 17788           Poor_Support
# 17798    Switched_Competitor
# 17837          Too_Expensive
# 17865          Too_Expensive
# 17871       Missing_Features
# 17872       Missing_Features
# 17887       Missing_Features
# 17923          Too_Expensive
# 17933    Switched_Competitor
# 17938       Missing_Features
# 17946       No_Longer_Needed
# 17947       Missing_Features
# 17972          Too_Expensive
# 17991       No_Longer_Needed
# 17996       Missing_Features
# 18001           Poor_Support
# 18035          Too_Expensive
# 18068           Poor_Support
# 18073       Missing_Features
# 18080    Switched_Competitor
# 18083          Too_Expensive
# 18092           Poor_Support
# 18107       Missing_Features
# 18112       No_Longer_Needed
# 18125           Poor_Support
# 18149           Poor_Support
# 18178          Too_Expensive
# 18192       Missing_Features
# 18196    Switched_Competitor
# 18214          Too_Expensive
# 18221       No_Longer_Needed
# 18224          Too_Expensive
# 18240          Too_Expensive
# 18247       Missing_Features
# 18273           Poor_Support
# 18278          Too_Expensive
# 18300           Poor_Support
# 18306          Too_Expensive
# 18307          Too_Expensive
# 18313    Switched_Competitor
# 18334    Switched_Competitor
# 18337          Too_Expensive
# 18373           Poor_Support
# 18375           Poor_Support
# 18382       No_Longer_Needed
# 18402          Too_Expensive
# 18413          Too_Expensive
# 18428       Missing_Features
# 18431          Too_Expensive
# 18432          Too_Expensive
# 18435          Too_Expensive
# 18443          Too_Expensive
# 18453           Poor_Support
# 18464           Poor_Support
# 18474    Switched_Competitor
# 18476           Poor_Support
# 18500           Poor_Support
# 18505          Too_Expensive
# 18549    Switched_Competitor
# 18554          Too_Expensive
# 18556       Missing_Features
# 18563    Switched_Competitor
# 18575           Poor_Support
# 18593          Too_Expensive
# 18597          Too_Expensive
# 18632       Missing_Features
# 18642       Missing_Features
# 18647    Switched_Competitor
# 18650       Missing_Features
# 18656          Too_Expensive
# 18688       Missing_Features
# 18705    Switched_Competitor
# 18721       Missing_Features
# 18722       No_Longer_Needed
# 18734    Switched_Competitor
# 18761          Too_Expensive
# 18768           Poor_Support
# 18772          Too_Expensive
# 18777          Too_Expensive
# 18805           Poor_Support
# 18814    Switched_Competitor
# 18824          Too_Expensive
# 18834          Too_Expensive
# 18842           Poor_Support
# 18848       Missing_Features
# 18861    Switched_Competitor
# 18868    Switched_Competitor
# 18891          Too_Expensive
# 18931           Poor_Support
# 18933    Switched_Competitor
# 18935           Poor_Support
# 18941       No_Longer_Needed
# 18946       Missing_Features
# 18956           Poor_Support
# 18973    Switched_Competitor
# 18985           Poor_Support
# 18988       Missing_Features
# 19002    Switched_Competitor
# 19024          Too_Expensive
# 19027    Switched_Competitor
# 19041           Poor_Support
# 19043    Switched_Competitor
# 19049          Too_Expensive
# 19050       Missing_Features
# 19081    Switched_Competitor
# 19083    Switched_Competitor
# 19128       Missing_Features
# 19144       Missing_Features
# 19147          Too_Expensive
# 19169       Missing_Features
# 19189          Too_Expensive
# 19198    Switched_Competitor
# 19212          Too_Expensive
# 19234    Switched_Competitor
# 19241          Too_Expensive
# 19248    Switched_Competitor
# 19253       Missing_Features
# 19256           Poor_Support
# 19263          Too_Expensive
# 19274    Switched_Competitor
# 19287          Too_Expensive
# 19294          Too_Expensive
# 19303       Missing_Features
# 19307          Too_Expensive
# 19322           Poor_Support
# 19350           Poor_Support
# 19366    Switched_Competitor
# 19369    Switched_Competitor
# 19370       No_Longer_Needed
# 19373          Too_Expensive
# 19384          Too_Expensive
# 19395           Poor_Support
# 19396       No_Longer_Needed
# 19407           Poor_Support
# Name: cancellation_reason, dtype: object
